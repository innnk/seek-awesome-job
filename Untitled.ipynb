# %%
import sys
import time
import requests
from lxml import etree
import json
import random
from bs4 import BeautifulSoup
import lxml

# %%
base_url='https://www.lagou.com/jobs/list_%s?px=default&city=%s'
position = '深度学习'
city = '北京'
#url=base_url % (position, city)
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36',
        'Cookie':'user_trace_token=20170425200852-dfbddc2c21fd492caac33936c08aef7e; LGUID=20170425200852-f2e56fe3-29af-11e7-b359-5254005c3644; showExpriedIndex=1; showExpriedCompanyHome=1; showExpriedMyPublish=1; hasDeliver=22; index_location_city=%E5%85%A8%E5%9B%BD; JSESSIONID=CEB4F9FAD55FDA93B8B43DC64F6D3DB8; TG-TRACK-CODE=search_code; SEARCH_ID=b642e683bb424e7f8622b0c6a17ffeeb; Hm_lvt_4233e74dff0ae5bd0a3d81c6ccf756e6=1493122129,1493380366; Hm_lpvt_4233e74dff0ae5bd0a3d81c6ccf756e6=1493383810; _ga=GA1.2.1167865619.1493122129; LGSID=20170428195247-32c086bf-2c09-11e7-871f-525400f775ce; LGRID=20170428205011-376bf3ce-2c11-11e7-8724-525400f775ce; _putrc=AFBE3C2EAEBB8730',
        'Host':'www.lagou.com',
        'Origin':'https://www.lagou.com'
    }

# %%
html=requests.get(url,headers=headers).content

# %%
jd = json.loads(html.decode('utf-8'))

# %%
html.decode('utf-8')
# Out:
# '{"success":false,"msg":"您操作太频繁,请稍后再访问","clientIp":"114.241.210.161"}\n'

# %%
selector=etree.HTML(html)

# %%
total_page
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-88e6b29c2372> in <module>()
# ----> 1 total_page
#
# NameError: name 'total_page' is not defined

# %%
total_page=selector.xpath('//ul[@id="order"]/li/div[4]/div[3]/span[2]/text()')[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-1204c5f01702> in <module>()
# ----> 1 total_page=selector.xpath('//ul[@id="order"]/li/div[4]/div[3]/span[2]/text()')[0]
#
# IndexError: list index out of range

# %%
  headers = {
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36',
        'Cookie':'user_trace_token=20180511181217-522dc145-abe2-4ff7-a984-8940b88d616b; _ga=GA1.2.640551932.1526033540; LGUID=20180511181220-ca6b61cf-5503-11e8-963a-525400f775ce; _gid=GA1.2.576696386.1526033541; LG_LOGIN_USER_ID=12b1a76c934424bb492259935bdb708685857991d40fa366; showExpriedIndex=1; showExpriedCompanyHome=1; showExpriedMyPublish=1; hasDeliver=29; index_location_city=%E5%8C%97%E4%BA%AC; WEBTJ-ID=05112018%2C184526-1634ece354014e-08b31f6a05750f-3b7c015b-2073600-1634ece35443c6; Hm_lvt_4233e74dff0ae5bd0a3d81c6ccf756e6=1526033540,1526034013,1526035527; _putrc=EE234AF85556A3F7; JSESSIONID=ABAAABAAAGGABCBE74B4F89F718508E2B6F7BF0818CA8D9; login=true; unick=%E5%B0%B9%E5%87%AF; TG-TRACK-CODE=index_search; LGSID=20180511230112-2510bc2a-552c-11e8-821a-5254005c3644; PRE_UTM=; PRE_HOST=; PRE_SITE=; PRE_LAND=https%3A%2F%2Fwww.lagou.com%2Fjobs%2Flist_%25E6%25B7%25B1%25E5%25BA%25A6%25E5%25AD%25A6%25E4%25B9%25A0%3Fpx%3Ddefault%26city%3D%25E5%258C%2597%25E4%25BA%25AC; gate_login_token=c570246d0ed097480a4945673864b6410f3318710c2bbffe; LGRID=20180511230841-30aa5e43-552d-11e8-96ec-525400f775ce; Hm_lpvt_4233e74dff0ae5bd0a3d81c6ccf756e6=1526051322; SEARCH_ID=1e2d96483b254d6486bcdf004eb81cbd',
        'Host':'www.lagou.com',
        'Origin':'https://www.lagou.com',
       # 'Referer':' https://www.lagou.com/jobs/',
    }

# %% [markdown]
# user_trace_token=20180511181217-522dc145-abe2-4ff7-a984-8940b88d616b; _ga=GA1.2.640551932.1526033540; LGUID=20180511181220-ca6b61cf-5503-11e8-963a-525400f775ce; _gid=GA1.2.576696386.1526033541; LG_LOGIN_USER_ID=12b1a76c934424bb492259935bdb708685857991d40fa366; showExpriedIndex=1; showExpriedCompanyHome=1; showExpriedMyPublish=1; hasDeliver=29; index_location_city=%E5%8C%97%E4%BA%AC; WEBTJ-ID=05112018%2C184526-1634ece354014e-08b31f6a05750f-3b7c015b-2073600-1634ece35443c6; Hm_lvt_4233e74dff0ae5bd0a3d81c6ccf756e6=1526033540,1526034013,1526035527; _putrc=EE234AF85556A3F7; JSESSIONID=ABAAABAAAGGABCBE74B4F89F718508E2B6F7BF0818CA8D9; login=true; unick=%E5%B0%B9%E5%87%AF; TG-TRACK-CODE=index_search; LGSID=20180511230112-2510bc2a-552c-11e8-821a-5254005c3644; PRE_UTM=; PRE_HOST=; PRE_SITE=; PRE_LAND=https%3A%2F%2Fwww.lagou.com%2Fjobs%2Flist_%25E6%25B7%25B1%25E5%25BA%25A6%25E5%25AD%25A6%25E4%25B9%25A0%3Fpx%3Ddefault%26city%3D%25E5%258C%2597%25E4%25BA%25AC; gate_login_token=c570246d0ed097480a4945673864b6410f3318710c2bbffe; _gat=1; Hm_lpvt_4233e74dff0ae5bd0a3d81c6ccf756e6=1526051533; LGRID=20180511231213-aefc958e-552d-11e8-96ec-525400f775ce; SEARCH_ID=674fd2963439437d859c543711bd6060

# %%
post_data={"first":"true",
                       'pn':'1',
                       'kd':'深度学习'
            }

# %%
url = 'https://www.lagou.com/jobs/positionAjax.json?px=default&city=''北京'"&needAddtionalResult=false'
# Out:
#   File "<ipython-input-4-a0705a41c803>", line 1
#     url = 'https://www.lagou.com/jobs/positionAjax.json?px=default&city=''北京'"&needAddtionalResult=false'
#                                                                                                          ^
# SyntaxError: EOL while scanning string literal

# %%
data=requests.post(url,data=post_data,headers=headers).content

# %%
data
# Out:
# b'{"success":false,"msg":"\xe6\x82\xa8\xe6\x93\x8d\xe4\xbd\x9c\xe5\xa4\xaa\xe9\xa2\x91\xe7\xb9\x81,\xe8\xaf\xb7\xe7\xa8\x8d\xe5\x90\x8e\xe5\x86\x8d\xe8\xae\xbf\xe9\x97\xae","clientIp":"114.248.131.187"}\n'

# %%
data.decode('utf-8')
# Out:
# '{"success":false,"msg":"您操作太频繁,请稍后再访问","clientIp":"114.248.131.187"}\n'

# %%
json_url= 'https://www.lagou.com/jobs/positionAjax.json?px=default&city=%s&needAddtionalResult=false'

# %%
url=json_url % '北京'

# %%
url
# Out:
# 'https://www.lagou.com/jobs/positionAjax.json?px=default&city=北京&needAddtionalResult=false'

# %%
import urllib.request
from bs4 import BeautifulSoup
#访问免费ip代理网址:http://www.youdaili.net/Daili/http/29381.html,处理得到所有的ip
def htmlParser(url):
    iplist=[]
    #设置头部
    user_agent = 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36'
    headers = {"User-Agent": user_agent}
    req = urllib.request.Request(url, headers=headers)
    #获取页面html
    html=urllib.request.urlopen(req).read()
    soup=BeautifulSoup(html,'html.parser')
    datas=soup.find("div",{"class":"content"}).findAll("p")
    for data in datas:
        ip=data.get_text().split("@")[0]
        iplist.append(ip)
    return iplist

# %%
def confirm_ip(ip):
    #配置proxy
    proxy={'http':'http://%s'%ip}
    proxy_handler=urllib.request.ProxyHandler(proxy)
    proxy=urllib.request.build_handler(proxy_handler)
    urllib.request.install_handler(proxy)
 
    #用百度首页检测代理ip
    test_url="http://www.baidu.com"
    user_agent = 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36'
    headers = {"User-Agent": user_agent}
    req = urllib.request.Request(test_url, headers=headers)
 
    try:
        response=urllib.request.urlopen(req)
        content=response.read()
        #获取到内容
        if content:
            print("its a right ip")
            return ip
        #没有获取到
        else:
            return None
    #访问错误
    except urllib.request.URLError as e:
        print(e.reason)
        return None
 
trueIp=[]
url="http://www.youdaili.net/Daili/http/36815.html"
iplist=htmlParser(url)
for ip in iplist:
    if confirm_ip(ip)!=None:
       trueIp.append(ip)
 
print(trueIp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-72cc771d0c34> in <module>()
#      31 iplist=htmlParser(url)
#      32 for ip in iplist:
# ---> 33     if confirm_ip(ip)!=None:
#      34        trueIp.append(ip)
#      35
#
# <ipython-input-23-72cc771d0c34> in confirm_ip(ip)
#       3     proxy={'http':'http://%s'%ip}
#       4     proxy_handler=urllib.request.ProxyHandler(proxy)
# ----> 5     proxy=urllib.request.build_handler(proxy_handler)
#       6     urllib.request.install_handler(proxy)
#       7
#
# AttributeError: module 'urllib.request' has no attribute 'build_handler'

# %%
url = 'https://www.zhipin.com/c101010100/h_101010100/?query=%E6%B7%B1%E5%BA%A6%E5%AD%A6%E4%B9%A0&page=1&ka=page-1'

# %%
headers = {
        'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:60.0) Gecko/20100101 Firefox/60.0',
        'cookie':'t=8PhrsKYhfhfcTfQs; wt=8PhrsKYhfhfcTfQs; sid=sem_pz_bdpc_dasou_title; JSESSIONID=""; Hm_lvt_194df3105ad7148dcf2b98a91b5e727a=1526090478,1526090798,1526114945; __c=1526114945; __g=sem_pz_bdpc_dasou_title; __l=l=%2Fwww.zhipin.com%2F%3Fsid%3Dsem_pz_bdpc_dasou_title&r=https%3A%2F%2Fwww.baidu.com%2Fs%3Fwd%3Dboss%25E7%259B%25B4%25E8%2581%2598%26rsv_spt%3D1%26rsv_iqid%3D0x80a67c4200016ad7%26issp%3D1%26f%3D8%26rsv_bp%3D1%26rsv_idx%3D2%26ie%3Dutf-8%26rqlang%3Dcn%26tn%3Dbaiduhome_pg%26rsv_enter%3D1%26oq%3Dqoo%26rsv_t%3D2b5ev7NGtE%252BFwnua%252BSVfGm8f23Ku%252F2qoR4KHkhJQxh%252BavX4Q4ak21DEF%252FVZ7aKFKWu9E%26inputT%3D1886%26rsv_pq%3Dd1f22f9c0001939a%26rsv_sug3%3D10%26rsv_sug1%3D9%26rsv_sug7%3D100%26bs%3Dqoo&g=%2Fwww.zhipin.com%2F%3Fsid%3Dsem_pz_bdpc_dasou_title; lastCity=101010100; __a=89011344.1526090474.1526090487.1526114945.25.3.14.14; Hm_lpvt_194df3105ad7148dcf2b98a91b5e727a=1526117856'
    
    }

# %%
res = requests.get(url, headers=headers)

# %%
# Out:
# '\n<!DOCTYPE html>\n\n<html>\n<head>\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n<title>BOSS直聘验证码</title>\n<style>\n* { margin:0; padding:0;}\nbody,input,button { font-family:arial,helvetica,Microsoft Yahei; line-height:1.5; font-size:14px;}\nbody { background-color:#F7F9FC;}\n.capcha-box { width:300px; margin:0 auto; padding:30px 50px; margin-top:100px; border-radius:5px; background-color:#fff;}\n.capcha-box .logo { text-align:center;}\n.capcha-box .logo img { width:50px; height:50px; margin:0 auto;}\n.capcha-box .tips { color:#999; padding: 20px 0;}\n.ipt { padding: 8px 10px; line-height: 24px; min-height: 22px; width: 140px; border: 1px #ddd solid; border-radius: 3px; outline:none;}\n.ipt:focus { border-color:#59CAC2;}\n.ipt:focus,.btn:hover { -webkit-transition: all linear .2s; -moz-transition: all linear .2s; -o-transition: all linear .2s; transition: all linear .2s;}\n.btn { background: #59CAC2; color: #fff; line-height: 40px; text-align: center; width
# ...

# %%
soup = BeautifulSoup(res.text, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7 ]><html class="ie ie6"><![endif]--><!--[if IE 7 ]><html class="ie ie7"><![endif]--><!--[if IE 8 ]><html class="ie ie8"><![endif]--><!--[if IE 9 ]><html class="ie9"><![endif]--><!--[if (gt IE 9)|!(IE)]><!--><html class="standard"><!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <title>【北京深度学习招聘】2018年北京深度学习最新人才招聘信息-BOSS直聘</title>
# <meta content="北京深度学习招聘,北京深度学习人才网,北京深度学习招聘网" name="keywords"/>
# <meta content="BOSS直聘为求职者提供2018年最新的北京深度学习招聘信息，百万Boss在线直聘，直接开聊，在线面试，找工作就上BOSS直聘网站或APP，直接与Boss开聊吧！" name="description"/>
# <link href="https://static.zhipin.com/zhipin/v40/web/geek/css/main.css" rel="stylesheet" type="text/css"/>
# <script>
#         var positionList = [];
#     </script>
# </head>
# <body>
# <div id="wrap">
# <script>
#     var staticPath = 'https://static.zhipin.com/zhipin/v40';
#     _PAGE={
#         checkMobileUrl:"/registe/sendSms.json",
#         regMobileUrl:"/registe/save.json",
#         loginMobileUrl:"/login/phone.json",
# ...

# %%
titles = soup.select('.job-title')

# %%
titles
# Out:
# [<div class="job-title">深度学习算法工程师</div>,
#  <div class="job-title">人工智能-深度学习-机器学习</div>,
#  <div class="job-title">人工智能/深度学习算法工程师</div>,
#  <div class="job-title">深度学习</div>,
#  <div class="job-title">深度学习nlp方向</div>,
#  <div class="job-title">深度学习</div>,
#  <div class="job-title">深度学习</div>,
#  <div class="job-title">AI LABS-深度学习算法工程师</div>,
#  <div class="job-title">深度学习算法科学家</div>,
#  <div class="job-title">深度学习算法工程师</div>,
#  <div class="job-title">深度学习算法研究员</div>,
#  <div class="job-title">深度学习</div>,
#  <div class="job-title">深度学习算法工程师</div>,
#  <div class="job-title">深度学习工程师</div>,
#  <div class="job-title">深度学习</div>,
#  <div class="job-title">深度学习工程师</div>,
#  <div class="job-title">深度学习算法工程师</div>,
#  <div class="job-title">深度学习高级算法工程师</div>,
#  <div class="job-title">深度学习</div>,
#  <div class="job-title">深度学习开发工程师</div>,
#  <div class="job-title">深度学习-北京</div>,
#  <div class="job-title">深度学习算法</div>,
#  <div class="job-title">深度学习高级算法工程师</div>,
# ...

# %%
web = soup.select('.info-primary > h3 > a')

# %%
web[29]
# Out:
# <a data-index="30" data-itemid="30" data-jid="026a25a1005b18c51nx63tu-F1U~" data-jobid="18056377" data-lid="Sz8kMW60Ef.search" href="/job_detail/026a25a1005b18c51nx63tu-F1U~.html" ka="search_list_30" target="_blank">
# <div class="job-title">深度学习算法工程师/专家</div>
# <span class="red">25k-40k</span>
# <div class="info-detail"></div>
# </a>

# %%
jobDetailUrl = 'https://www.zhipin.com/' + web[0]['href']

# %%
html='''
<a class="css" href="http://example.com/test" id="test"><!--test --></a>
'''
bs=BeautifulSoup(html,"html.parser")
print(bs.a)
print(bs.a.string)
# Out:
# <a class="css" href="http://example.com/test" id="test"><!--test --></a>
# test

# %%
detailSoup = BeautifulSoup(detailRequest.text, 'html.parser')

# %%
detailSoup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7 ]><html class="ie ie6"><![endif]-->
# <!--[if IE 7 ]><html class="ie ie7"><![endif]-->
# <!--[if IE 8 ]><html class="ie ie8"><![endif]-->
# <!--[if IE 9 ]><html class="ie9"><![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!--><html class="standard"><!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <title>【深度学习算法工程师招聘】易车网招聘-BOSS直聘</title>
# <meta content="深度学习算法工程师,深度学习算法工程师招聘,易车网深度学习算法工程师招聘" name="keywords">
# <meta content="易车网招聘深度学习算法工程师牛人,更多易车网深度学习算法工程师招聘信息,请登录BOSS直聘查看详细的易车网对深度学习算法工程师岗位牛人的岗位职责要求、工作内容说明、薪资待遇介绍等招聘信息。" name="description"/>
# <link href="https://m.zhipin.com/job_detail/01abc9df58ac8b5b1XR_3dm0FlQ~.html" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link href="https://static.zhipin.com/zhipin/v40/web/geek/css/main.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#         var _userInfo = {
#             showTip:false,
#             text:'',
#             isLogin:true,
# ...

# %%
lng, Lat = map(float, detailSoup.select('.map-container')[0]['data-long-lat'].split(','))

# %%
type(lng)
# Out:
# float

# %%
c
# Out:
# 116.327697

# %%
    for title, company, red, info, company_info in zip(titles, companys, reds, infos, company_infos):
        #使用正则获取info和company里面的信息
        re_info = re.findall('<p>(.*)  <em class="vline"></em>(.*)<em class="vline"></em>(.*)</p>', str(info))
        re_company = re.findall('<p>(.*)<em class="vline"></em>(.*)<em class="vline"></em>(.*)</p>', str(company_info))
        #将数据存放在data中
        try:
            data = {
                #'工作岗位': title.text.strip(),
                '公司名称': company.text.strip(),
                '工资': red.text.strip(),
                #'工作地点': re_info[0][0],
                #'工作经历': re_info[0][1],
                #'学历要求': re_info[0][2],
                '公司类型': re_company[0][0],
                '公司投资': re_company[0][1],
                '公司人数': re_company[0][2]
            }
        except:
            continue

# %%
data
# Out:
# {'公司人数': '0-20人', '公司名称': '怀若', '公司投资': 'A轮', '公司类型': '计算机软件', '工资': '20k-40k'}

# %%
conn = sqlite3.connect('test.db')
cursor = conn.cursor()

# %%
cursor.execute("""create table catalog (

    nums varchar(10) primary key,

    comname varchar(10),

    status varchar(10),
    
    comtype varchar(10),
    
    salary varchar(10)

   )""")

# %%
cursor.execute("insert into catalog values('0-20人','怀若','A轮','计算机软件','20k-40k')")

# %%
cursor.rowcount
# Out:
# 1

# %%
cursor.close()
conn.commit()
conn.close()

# %%
 conn = sqlite3.connect('test.db')
cursor = conn.cursor()

# %%
a = cursor.execute('select * from catalog where nums=?', ('0-20人',))

# %%
b= cursor.fetchall()

# %%
b
# Out:
# [('0-20人', '怀若', 'A轮', '计算机软件', '20k-40k')]

# %%
baseUrls = ['https://www.zhipin.com/c101010100/h_101010100/?query=' + jobname + '&page=' + format(str(i)) for i in range(1,20)]

# %%
jobname = '深度学习'

# %%
baseUrls
# Out:
# ['https://www.zhipin.com/c101010100/h_101010100/?query=深度学习&page=1',
#  'https://www.zhipin.com/c101010100/h_101010100/?query=深度学习&page=2',
#  'https://www.zhipin.com/c101010100/h_101010100/?query=深度学习&page=3',
#  'https://www.zhipin.com/c101010100/h_101010100/?query=深度学习&page=4',
#  'https://www.zhipin.com/c101010100/h_101010100/?query=深度学习&page=5',
#  'https://www.zhipin.com/c101010100/h_101010100/?query=深度学习&page=6',
#  'https://www.zhipin.com/c101010100/h_101010100/?query=深度学习&page=7',
#  'https://www.zhipin.com/c101010100/h_101010100/?query=深度学习&page=8',
#  'https://www.zhipin.com/c101010100/h_101010100/?query=深度学习&page=9',
#  'https://www.zhipin.com/c101010100/h_101010100/?query=深度学习&page=10',
#  'https://www.zhipin.com/c101010100/h_101010100/?query=深度学习&page=11',
#  'https://www.zhipin.com/c101010100/h_101010100/?query=深度学习&page=12',
#  'https://www.zhipin.com/c101010100/h_101010100/?query=深度学习&page=13',
#  'https://www.zhipin.com/c101010100/h_101010100/?query=深度学习&page=14',
# ...

# %%
a = [<span class="red">25k-50k</span>]
# Out:
#   File "<ipython-input-6-a10a2ff28346>", line 1
#     a = [<span class="red">25k-50k</span>]
#          ^
# SyntaxError: invalid syntax

# %%
b = '20k-40k'

# %%
b.split('k-')
# Out:
# ['20', '40k']

# %%
filterCondition = {'employeesNumber':'500', 'salary' : 15, 'distance' : '20'}

# %%
filterCondition
# Out:
# {'distance': '20', 'employeesNumber': '500', 'salary': 15}

# %%
b = '''
a href="/job_detail/0f0f8a7f5003f7781XR-2t65F1M~.html?ka=search_list_1" data-jid="0f0f8a7f5003f7781XR-2t65F1M~" data-itemid="1" data-lid="RKdLWRCnJn.search" data-jobid="20413471" data-index="1" ka="search_list_1" target="_blank">
                                                <div class="job-title">人工智能/深度学习算法工程师</div>
                                                <span class="red">20k-30k</span>
                                                <div class="info-detail" style="top: 0px;"></div>
                                            </a>'''

# %%
c = BeautifulSoup(b, 'lxml')

# %%
c
# Out:
# <html><body><p>a href="/job_detail/0f0f8a7f5003f7781XR-2t65F1M~.html?ka=search_list_1" data-jid="0f0f8a7f5003f7781XR-2t65F1M~" data-itemid="1" data-lid="RKdLWRCnJn.search" data-jobid="20413471" data-index="1" ka="search_list_1" target="_blank"&gt;
#                                                 </p><div class="job-title">人工智能/深度学习算法工程师</div>
# <span class="red">20k-30k</span>
# <div class="info-detail" style="top: 0px;"></div>
# </body></html>

# %%
d= c.p.contents

# %%
print(d)
# Out:
# ['a href="/job_detail/0f0f8a7f5003f7781XR-2t65F1M~.html?ka=search_list_1" data-jid="0f0f8a7f5003f7781XR-2t65F1M~" data-itemid="1" data-lid="RKdLWRCnJn.search" data-jobid="20413471" data-index="1" ka="search_list_1" target="_blank">\n                                                ']

# %%
d[0].split('"')[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-e8236186c13a> in <module>()
# ----> 1 d[0].split('"')[1]
#
# ~/anaconda3/lib/python3.6/site-packages/bs4/element.py in __getitem__(self, key)
#    1009         """tag[key] returns the value of the 'key' attribute for the tag,
#    1010         and throws an exception if it's not there."""
# -> 1011         return self.attrs[key]
#    1012
#    1013     def __iter__(self):
#
# KeyError: 0

# %%
a = []

# %%
a().find()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-9f5b23b3a3d9> in <module>()
# ----> 1 a().find()
#
# TypeError: 'list' object is not callable

# %%
a =(1,2,3 )

# %%
type(a)
# Out:
# tuple

# %%
import sqlite3
conn = sqlite3.connect('/home/innnk/project/papapa/test.db')
import pandas as pd

# %%
cursor = conn.cursor()

# %%
conn.row_factory= sqlite3 .Row

# %%
datafrom = cursor.execute("select * from jobinfo")

# %%
print(cursor.fetchall())
# Out:
# [(None, '易车网', '20k-40k', '已上市', '1000-9999人', '北京市 海淀区 腾达大厦裙楼', '10301.242444327', 'https://www.zhipin.com//job_detail/01abc9df58ac8b5b1XR_3dm0FlQ~.html'), (None, '中科软', '15k-20k', '已上市', '10000人以上', '北京市海淀区中关村中科软商务楼', '14969.1313766557', 'https://www.zhipin.com//job_detail/10d57cf58e1b19911XR_3NS6FFE~.html'), (None, '北京东舟技术有限公司', '20k-30k', '未融资', '20-99人', '北京海淀区数字传媒大厦1号楼203', '21655.3744512614', 'https://www.zhipin.com//job_detail/0f0f8a7f5003f7781XR-2t65F1M~.html'), (None, '米文动力', '15k-30k', 'A轮', '20-99人', '北京海淀区城建大厦A1408', '14786.0889536345', 'https://www.zhipin.com//job_detail/1ac0d6ef3be3dd2a1XRy3Nm6F1s~.html'), (None, '京东集团', '30k-60k', '已上市', '10000人以上', '北京大兴区京东集团总部', '23642.1414694713', 'https://www.zhipin.com//job_detail/e87598c3131d90a11XRy09-6EVo~.html'), (None, '猎户星空', '25k-50k', 'A轮', '100-499人', '北京朝阳区盈科中心C座3层', '16710.2418655156', 'https://www.zhipin.com//job_detail/05a9204dbe5e942c1XR829S_FVQ~.html'), (None, '搜狗', '30k-50k', '已上市', '1000-9999人', '北京海淀区中关村搜狐大厦', '
# ...

# %%
para = "select * from jobinfo"

# %%
df = pd.read_sql(para, conn )

# %%
df.describe()
# Out:
#         distance
# count  55.000000
# mean   18.011412
# std     3.300797
# min    12.375699
# 25%    15.536307
# 50%    16.399367
# 75%    21.754801
# max    22.431905
